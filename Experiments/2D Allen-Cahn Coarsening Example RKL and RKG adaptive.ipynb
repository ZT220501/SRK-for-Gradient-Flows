# %%
import numpy as np
import matplotlib.pyplot as plt
import math
from scipy import interpolate
from numpy import float64
import time

# %%
import sys
import os
import importlib


# Get the parent directory of the current file
parent_dir = os.path.abspath(os.path.join(os.getcwd(), '..'))
if parent_dir not in sys.path:
    sys.path.insert(0, parent_dir)

import methods
importlib.reload(methods)
import solvers
importlib.reload(solvers)
import utils
importlib.reload(utils)
# Out:
# <module 'utils' from 'd:\\PhD at UCLA\\Allen-Cahn and Cahn-Hilliard\\Stabilized_RK_Allen_Cahn_Cahn_Hillard\\SRK\\utils.py'>

# %%
# Time and space range
a_x = 0
b_x = 2 * np.pi
a_y = 0
b_y = 2 * np.pi

s = 10

#Initial x grid size and t grid size
Nx = 512
Ny = 512

dx = float64((b_x - a_x) / Nx)
dy = float64((b_y - a_y) / Ny)

T = 20
eps = 0.1

# dt = 1 * dx**4 / eps**2
dt = 1e-1

bc= "Periodic"
adaptive_timestep_tolerance = 1e-3

save = False
save_path = "../../Results/Allen_Cahn_Comparison"

print("Initial dt used is " + str(dt))
print("eps used is " + str(eps))
print("4 * dt / dx^2 is " + str(4 * dt / dx**2))
# Out:
# Initial dt used is 0.1
# eps used is 0.1
# 4 * dt / dx^2 is 2656.0740364736994

# %%
'''
Initial Condition for the Allen-Cahn simulation
'''
def initial_condition(mesh_grid):
    X, Y = mesh_grid
    np.random.seed(12345)
    return 0.5 * np.random.uniform(-1, 1, size=X.shape).astype(np.float64)

# %%
method = "RKL2_2D"
# method = "RKG2_2D"

# %%
if method == "RKL2_2D":
    my_solver = solvers.Allen_Cahn_Solver_2D_Adaptive_Timestep("RKL2_2D", s, Nx, Ny, dt, dx, dy, a_x, b_x, a_y, b_y, initial_condition, T, eps, bc=bc, energy_case=3, plot_frequency=20, splitting_order="NLN", save=save, save_path=save_path, adaptive_timestep_tolerance=adaptive_timestep_tolerance)
elif method == "RKG2_2D":
    my_solver = solvers.Allen_Cahn_Solver_2D_Adaptive_Timestep("RKG2_2D", s, Nx, Ny, dt, dx, dy, a_x, b_x, a_y, b_y, initial_condition, T, eps, bc=bc, energy_case=3, plot_frequency=20, splitting_order="NLN", save=save, save_path=save_path, adaptive_timestep_tolerance=adaptive_timestep_tolerance)
else:
    raise ValueError("Invalid method")
    
my_solver.initialize(display=True)

# %%
my_solver.solve()
# Out:
# Current dt is 0.1, current s is 10
# Max value of u_total[-1] is 0.4999976341091975
# Min value of u_total[-1] is -0.499999759077836
# Length of u_total is 2
# Length of t_total is 2
# Current dt is 0.1, current s is 10
# Length of u_total is 3
# Length of t_total is 3
# LTE is 0.31297956387755704
# Current dt is 0.1, current s is 10
# Length of u_total is 4
# Length of t_total is 4
# LTE is 0.07379579685179116
# Current dt is 0.1, current s is 10
# Length of u_total is 5
# Length of t_total is 5
# LTE is 0.0021917043510611967
# Current dt is 0.1, current s is 10
# Length of u_total is 6
# Length of t_total is 6
# LTE is 0.010411037589982852
# Current dt is 0.1, current s is 10
# Length of u_total is 7
# Length of t_total is 7
# LTE is 0.023716158056928227
# Current dt is 0.1, current s is 10
# Length of u_total is 8
# Length of t_total is 8
# LTE is 0.028255184993512678
# Current dt is 0.1, current s is 10
# Length of u_total is 9
# Length of t_total is 9
# LTE is 0.037227619363594866
# Current dt is 0.1, current s is 10
# Length of u_total is 10
# Length of t_total is 10
# LTE is 0.032613917110174834
# Current dt is 0.1, current s is 10
# Length of u_total is 11
# Length of t_total is 11
# LTE is 0.02478679635739603
# Current dt is 0.1, current s is 10
# Length of u_total is 12
# Length of t_total is 12
# LTE is 0.02029801864746532
# Current dt is 0.1, current s is 10
# Length of u_total is 13
# Length of t_total is 13
# LTE is 0.014829073423616196
# Current dt is 0.1, current s is 10
# Length of u_total is 14
# Length of t_total is 14
# LTE is 0.00585605764392319
# Current dt is 0.1, current s is 10
# Length of u_total is 15
# Length of t_total is 15
# LTE is 0.003810186592715606
# Current dt is 0.1, current s is 10
# Length of u_total is 16
# Length of t_total is 16
# LTE is 0.0023588466279011455
# Current dt is 0.1, current s is 10
# Length of u_total is 17
# Length of t_total is 17
# LTE is 0.0013548124122616245
# Current dt is 0.1, current s is 10
# Length of u_total is 18
# Length of t_total is 18
# LTE is 0.0005687138375056883
# Current dt is 0.1, current s is 10
# Length of u_total is 19
# Length of t_total is 19
# LTE is 0.00015334313761673768
# Current dt is 0.1, current s is 10
# Length of u_total is 20
# Length of t_total is 20
# LTE is 0.0007233106201014472
# Current dt is 0.12, current s is 11
# Length of u_total is 21
# Length of t_total is 21
# LTE is 0.0028871148492083387
# Current dt is 0.12, current s is 11
# Max value of u_total[-1] is 0.11581391995548673
# Min value of u_total[-1] is -0.09676125138416809
# Length of u_total is 22
# Length of t_total is 22
# LTE is 0.001741887430322192
# Current dt is 0.12, current s is 11
# Length of u_total is 23
# Length of t_total is 23
# LTE is 0.0020789587747767624
# Current dt is 0.12, current s is 11
# Length of u_total is 24
# Length of t_total is 24
# LTE is 0.002168733253553587
# Current dt is 0.12, current s is 11
# Length of u_total is 25
# Length of t_total is 25
# LTE is 0.0019794000929168054
# Current dt is 0.12, current s is 11
# Length of u_total is 26
# Length of t_total is 26
# LTE is 0.0018309587068218725
# Current dt is 0.12, current s is 11
# Length of u_total is 27
# Length of t_total is 27
# LTE is 0.0016297757647850686
# Current dt is 0.12, current s is 11
# Length of u_total is 28
# Length of t_total is 28
# LTE is 0.001323877996212905
# Current dt is 0.12, current s is 11
# Length of u_total is 29
# Length of t_total is 29
# LTE is 0.0010300964236603233
# Current dt is 0.12, current s is 11
# Length of u_total is 30
# Length of t_total is 30
# LTE is 0.0006864462934201843
# Current dt is 0.12, current s is 11
# Length of u_total is 31
# Length of t_total is 31
# LTE is 0.0002895992782236817
# Current dt is 0.12, current s is 11
# Length of u_total is 32
# Length of t_total is 32
# LTE is 0.0006583152849465174
# Current dt is 0.144, current s is 12
# Length of u_total is 33
# Length of t_total is 33
# LTE is 0.0012771532421753662
# Current dt is 0.144, current s is 12
# Length of u_total is 34
# Length of t_total is 34
# LTE is 0.0034297124266989
# Current dt is 0.144, current s is 12
# Length of u_total is 35
# Length of t_total is 35
# LTE is 0.004212634242472785
# Current dt is 0.144, current s is 12
# Length of u_total is 36
# Length of t_total is 36
# LTE is 0.005098881201408154
# Current dt is 0.144, current s is 12
# Length of u_total is 37
# Length of t_total is 37
# LTE is 0.005971039380932172
# Current dt is 0.144, current s is 12
# Length of u_total is 38
# Length of t_total is 38
# LTE is 0.006621218261802911
# Current dt is 0.144, current s is 12
# Length of u_total is 39
# Length of t_total is 39
# LTE is 0.006192641376392999
# Current dt is 0.144, current s is 12
# Length of u_total is 40
# Length of t_total is 40
# LTE is 0.0052970369858250516
# Current dt is 0.144, current s is 12
# Length of u_total is 41
# Length of t_total is 41
# LTE is 0.004795417036198721
# Current dt is 0.144, current s is 12
# Max value of u_total[-1] is 0.6610413659635618
# Min value of u_total[-1] is -0.7030152138553484
# Length of u_total is 42
# Length of t_total is 42
# LTE is 0.002541945181714536
# Current dt is 0.144, current s is 12
# Length of u_total is 43
# Length of t_total is 43
# LTE is 0.002008793476316814
# Current dt is 0.144, current s is 12
# Length of u_total is 44
# Length of t_total is 44
# LTE is 0.0026926033114226117
# Current dt is 0.144, current s is 12
# Length of u_total is 45
# Length of t_total is 45
# LTE is 0.0031927392944289257
# Current dt is 0.144, current s is 12
# Length of u_total is 46
# Length of t_total is 46
# LTE is 0.0010458419562330706
# Current dt is 0.144, current s is 12
# Length of u_total is 47
# Length of t_total is 47
# LTE is 0.001790958145615959
# Current dt is 0.144, current s is 12
# Length of u_total is 48
# Length of t_total is 48
# LTE is 0.0024359000320766655
# Current dt is 0.144, current s is 12
# Length of u_total is 49
# Length of t_total is 49
# LTE is 0.0013898055004639004
# Current dt is 0.144, current s is 12
# Length of u_total is 50
# Length of t_total is 50
# LTE is 0.00013221908434106477
# Current dt is 0.144, current s is 12
# Length of u_total is 51
# Length of t_total is 51
# LTE is 0.0014774357387626197
# Current dt is 0.144, current s is 12
# Length of u_total is 52
# Length of t_total is 52
# LTE is 0.0016600616993385636
# Current dt is 0.144, current s is 12
# Length of u_total is 53
# Length of t_total is 53
# LTE is 0.0015694640863334886
# Current dt is 0.144, current s is 12
# Length of u_total is 54
# Length of t_total is 54
# LTE is 0.001120351840836184
# Current dt is 0.144, current s is 12
# Length of u_total is 55
# Length of t_total is 55
# LTE is 0.0009658661511629391
# Current dt is 0.144, current s is 12
# Length of u_total is 56
# Length of t_total is 56
# LTE is 0.0008279611020851063
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 57
# Length of t_total is 57
# LTE is 0.003099093723475707
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 58
# Length of t_total is 58
# LTE is 0.0008989053341403319
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 59
# Length of t_total is 59
# LTE is 0.002287056916667321
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 60
# Length of t_total is 60
# LTE is 0.00518958081626851
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 61
# Length of t_total is 61
# LTE is 0.0049185561313869475
# Current dt is 0.17279999999999998, current s is 13
# Max value of u_total[-1] is 0.996683060197963
# Min value of u_total[-1] is -0.9976672715947197
# Length of u_total is 62
# Length of t_total is 62
# LTE is 0.0015310515335279357
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 63
# Length of t_total is 63
# LTE is 0.0026591366608281625
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 64
# Length of t_total is 64
# LTE is 0.0030473471917094874
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 65
# Length of t_total is 65
# LTE is 0.0036300866750918065
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 66
# Length of t_total is 66
# LTE is 0.004335979588507052
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 67
# Length of t_total is 67
# LTE is 0.0054052390409945195
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 68
# Length of t_total is 68
# LTE is 0.006985910775237192
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 69
# Length of t_total is 69
# LTE is 0.009248106109355086
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 70
# Length of t_total is 70
# LTE is 0.011018377166956597
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 71
# Length of t_total is 71
# LTE is 0.0069448482663808375
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 72
# Length of t_total is 72
# LTE is 0.0014348576215266473
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 73
# Length of t_total is 73
# LTE is 0.010743383031504489
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 74
# Length of t_total is 74
# LTE is 0.016874751603707813
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 75
# Length of t_total is 75
# LTE is 0.03621117396404093
# Current dt is 0.17279999999999998, current s is 13
# Length of u_total is 76
# Length of t_total is 76
# LTE is 0.26690948773723244
# Current dt is 0.17279999999999998, current s is 13
# Energy is not monotone, at iteration 75!!!!!!!!!!!!!!!!
# Energy is 20428.3835662492 and the previous energy is 20299.174496839267
# Current dt is 0.13824, current s is 12
# Modified energy is not monotone, at iteration 75!!!!!!!!!!!!!!!!
# Modified energy is 20635.071966190422 and the previous modified energy is -5833.4252012133165
# Length of u_total is 77
# Length of t_total is 77
# LTE is 0.158582887004705
# Current dt is 0.13824, current s is 12
# Length of u_total is 78
# Length of t_total is 78
# LTE is 0.044409466760547384
# Current dt is 0.13824, current s is 12
# Length of u_total is 79
# Length of t_total is 79
# LTE is 0.022802408471613758
# Current dt is 0.13824, current s is 12
# Length of u_total is 80
# Length of t_total is 80
# LTE is 0.0025097478079615376
# Current dt is 0.13824, current s is 12
# Length of u_total is 81
# Length of t_total is 81
# LTE is 0.005903624376522948
# Current dt is 0.13824, current s is 12
# Max value of u_total[-1] is 0.9999864175858447
# Min value of u_total[-1] is -0.999990383001551
# Length of u_total is 82
# Length of t_total is 82
# LTE is 0.0049753247327085914
# Current dt is 0.13824, current s is 12
# Length of u_total is 83
# Length of t_total is 83
# LTE is 0.0012056067671418758
# Current dt is 0.13824, current s is 12
# Length of u_total is 84
# Length of t_total is 84
# LTE is 0.003351411715111899
# Current dt is 0.13824, current s is 12
# Length of u_total is 85
# Length of t_total is 85
# LTE is 0.0009553335907260818
# Current dt is 0.13824, current s is 12
# Length of u_total is 86
# Length of t_total is 86
# LTE is 0.006965692620453615
# Current dt is 0.13824, current s is 12
# Length of u_total is 87
# Length of t_total is 87
# LTE is 0.0030632905786106973
# Current dt is 0.13824, current s is 12
# Length of u_total is 88
# Length of t_total is 88
# LTE is 0.0021358959609373562
# Current dt is 0.13824, current s is 12
# Length of u_total is 89
# Length of t_total is 89
# LTE is 0.007724903658059917
# Current dt is 0.13824, current s is 12
# Length of u_total is 90
# Length of t_total is 90
# LTE is 0.012455043048392136
# Current dt is 0.13824, current s is 12
# Length of u_total is 91
# Length of t_total is 91
# LTE is 0.015302062356031779
# Current dt is 0.13824, current s is 12
# Length of u_total is 92
# Length of t_total is 92
# LTE is 0.015949329527607956
# Current dt is 0.13824, current s is 12
# Length of u_total is 93
# Length of t_total is 93
# LTE is 0.014806754621521367
# Current dt is 0.13824, current s is 12
# Length of u_total is 94
# Length of t_total is 94
# LTE is 0.010302643706052522
# Current dt is 0.13824, current s is 12
# Length of u_total is 95
# Length of t_total is 95
# LTE is 0.000549862623583211
# Current dt is 0.165888, current s is 13
# Length of u_total is 96
# Length of t_total is 96
# LTE is 0.0007411397254580634
# Current dt is 0.165888, current s is 13
# Length of u_total is 97
# Length of t_total is 97
# LTE is 0.0005684127700921401
# Current dt is 0.165888, current s is 13
# Length of u_total is 98
# Length of t_total is 98
# LTE is 0.0004655282328256474
# Current dt is 0.1990656, current s is 14
# Length of u_total is 99
# Length of t_total is 99
# LTE is 6.006001978344638e-05
# Current dt is 0.1990656, current s is 14
# Length of u_total is 100
# Length of t_total is 100
# LTE is 0.0005751335572907121
# Current dt is 0.1990656, current s is 14
# Length of u_total is 101
# Length of t_total is 101
# LTE is 0.0004579005064674138
# Current dt is 0.23887872, current s is 16
# Max value of u_total[-1] is 0.9999985341977866
# Min value of u_total[-1] is -0.9999998689278762
# Length of u_total is 102
# Length of t_total is 102
# LTE is 4.4043178865194044e-05
# Current dt is 0.23887872, current s is 16
# Length of u_total is 103
# Length of t_total is 103
# LTE is 0.000858831170683888
# Current dt is 0.23887872, current s is 16
# Length of u_total is 104
# Length of t_total is 104
# LTE is 0.0005891818534160542
# Current dt is 0.286654464, current s is 17
# Length of u_total is 105
# Length of t_total is 105
# LTE is 9.783991939599224e-06
# Current dt is 0.286654464, current s is 17
# Length of u_total is 106
# Length of t_total is 106
# LTE is 0.0009490479449561912
# Current dt is 0.286654464, current s is 17
# Length of u_total is 107
# Length of t_total is 107
# LTE is 0.0006840663048977291
# Current dt is 0.3439853568, current s is 19
# Modified energy is not monotone, at iteration 106!!!!!!!!!!!!!!!!
# Modified energy is 17015.522114260697 and the previous modified energy is 17000.694441005217
# Length of u_total is 108
# Length of t_total is 108
# LTE is 0.00018052305867304053
# Current dt is 0.3439853568, current s is 19
# Length of u_total is 109
# Length of t_total is 109
# LTE is 0.0010723167684959928
# Current dt is 0.3439853568, current s is 19
# Length of u_total is 110
# Length of t_total is 110
# LTE is 0.00064911548635678
# Current dt is 0.3439853568, current s is 19
# Length of u_total is 111
# Length of t_total is 111
# LTE is 0.0009105798111134211
# Current dt is 0.41278242815999994, current s is 20
# Modified energy is not monotone, at iteration 110!!!!!!!!!!!!!!!!
# Modified energy is 16718.87470902251 and the previous modified energy is 16663.03293484621
# Length of u_total is 112
# Length of t_total is 112
# LTE is 8.354665799939487e-05
# Current dt is 0.41278242815999994, current s is 20
# Energy is not monotone, at iteration 111!!!!!!!!!!!!!!!!
# Energy is 16146.225398831302 and the previous energy is 16144.142306674126
# Current dt is 0.33022594252799997, current s is 18
# Modified energy is not monotone, at iteration 111!!!!!!!!!!!!!!!!
# Modified energy is 16383.171663947529 and the previous modified energy is 16272.53745133878
# Length of u_total is 113
# Length of t_total is 113
# LTE is 0.006458546572383567
# Current dt is 0.33022594252799997, current s is 18
# Energy is not monotone, at iteration 112!!!!!!!!!!!!!!!!
# Energy is 17564.23139936414 and the previous energy is 16016.07027123469
# Current dt is 0.2641807540224, current s is 16
# Energy is not monotone, at iteration 112!!!!!!!!!!!!!!!!
# Energy is 17682.5789419704 and the previous energy is 16016.07027123469
# Current dt is 0.21134460321792, current s is 15
# Modified energy is not monotone, at iteration 112!!!!!!!!!!!!!!!!
# Modified energy is 16075.99180521252 and the previous modified energy is 5194.972684874587
# Length of u_total is 114
# Length of t_total is 114
# LTE is 0.0038755066508320835
# Current dt is 0.21134460321792, current s is 15
# Length of u_total is 115
# Length of t_total is 115
# LTE is 0.004410270351241918
# Current dt is 0.21134460321792, current s is 15
# Length of u_total is 116
# Length of t_total is 116
# LTE is 0.0018944221933574062
# Current dt is 0.21134460321792, current s is 15
# Length of u_total is 117
# Length of t_total is 117
# LTE is 0.0008643588338857894
# Current dt is 0.21134460321792, current s is 15
# Length of u_total is 118
# Length of t_total is 118
# LTE is 0.00010389854696006562
# Current dt is 0.253613523861504, current s is 16
# Length of u_total is 119
# Length of t_total is 119
# LTE is 0.0005940828371336082
# Current dt is 0.253613523861504, current s is 16
# Length of u_total is 120
# Length of t_total is 120
# LTE is 0.0006467553925740971
# Current dt is 0.253613523861504, current s is 16
# Length of u_total is 121
# Length of t_total is 121
# LTE is 0.0005789268065537062
# Current dt is 0.3043362286338048, current s is 18
# Max value of u_total[-1] is 0.9999995187458209
# Min value of u_total[-1] is -0.9999999651510706
# Modified energy is not monotone, at iteration 120!!!!!!!!!!!!!!!!
# Modified energy is 15652.743448962381 and the previous modified energy is 15634.725005211654
# Length of u_total is 122
# Length of t_total is 122
# LTE is 0.0005019827538493005
# Current dt is 0.3043362286338048, current s is 18
# Length of u_total is 123
# Length of t_total is 123
# LTE is 0.0010127672035802476

# %%
u_total, t_total, energy_total, energy_modified_total, mesh_grid = my_solver.get_results()

# %%
print(my_solver.running_time)
# Out:
# 83.95461535453796

# %%
def is_monotonic(array):
    return np.all(np.diff(array) <= 0)

# %%
energy_gradient_total = energy_total[:, 0]
energy_non_linear_total = energy_total[:, 1]
energy = energy_gradient_total + energy_non_linear_total

energy_modified_gradient_total = energy_modified_total[:, 0]
energy_modified_nonlinear_total = energy_modified_total[:, 1]
energy_modified = energy_modified_gradient_total + energy_modified_nonlinear_total

# Journal of Computational Physics (Elsevier): Times New Roman for figures
plt.rcParams["mathtext.fontset"] = "stix"
plt.rcParams["mathtext.rm"] = "Times New Roman"

fig, ax = plt.subplots(figsize=(6, 5), dpi=120)
# ax.plot(t_total, energy_gradient_total * dx**2, color="#2E86AB", lw=2, label="Gradient energy")
# ax.plot(t_total, energy_non_linear_total * dx**2, color="#A23B72", lw=2, label="Non-linear energy")
ax.plot(t_total[:], energy[:] * dx**2, color="#29cfcc", lw=2.5, label="Energy")
# ax.plot(t_total[:], energy_modified[:] * dx**2, color="red", lw=2.5, linestyle="--", label="Modified Energy")


from matplotlib.ticker import FuncFormatter, MultipleLocator

config_title = f"{save_path}/{method}/{method}_AC_comparison_Nx{Nx}_Ny{Ny}_dt{dt}_eps{eps:.4f}_T{T}_bc{bc}_energy_case3"


label_font = {"fontsize": 20, "fontfamily": "Times New Roman"}
# ax.yaxis.set_major_formatter(FuncFormatter(lambda x, p: f"{x/1e2:.0f}"))
# ax.yaxis.set_major_locator(MultipleLocator(100))
# ax.text(-0.01, 1.02, r"$\times\,10^{2}$",
#         transform=ax.transAxes,
#         fontsize=20,
#         fontfamily="Times New Roman",
#         va="bottom")
ax.tick_params(axis="both", labelsize=20)
for label in ax.get_xticklabels() + ax.get_yticklabels():
    label.set_fontfamily("Times New Roman")
# ax.legend(loc="best", frameon=True, prop={"family": "serif", "size": 14})
# ax.grid(True, linestyle="--", alpha=0.6)
ax.set_axisbelow(True)
ax.set_xticks([0, 2, 4, 6, 8])
ax.set_yticks([2, 4, 6, 8, 10])
fig.tight_layout()

ax.legend(loc="best", frameon=True, prop={"family": "Times New Roman", "size": 20})

if save:
    energy_save_path = f"{config_title}.pdf"
    fig.savefig(energy_save_path, bbox_inches="tight")
    print(f"Figure saved to {energy_save_path}")
plt.show()

# %%
print(is_monotonic(energy))
# Out:
# True

# %%
print(t_total[-1])
my_solver.display(u_total[-1], [a_x, b_x, a_y, b_y], t_total[-1], save=False)
# Out:
# 8.005600000000003

# %% [markdown]
# ### Generate animation

# %%
import matplotlib.animation as animation

# %%
# utils.generate_anime(u_total, t_total, [a_x, b_x, a_y, b_y], save=True)

# %%
# fig, ax = plt.subplots()
# cax = ax.imshow(u_total[0], cmap='viridis', origin='lower')
# fig.colorbar(cax)

# def update(frame):
#     cax.set_data(u_total[frame])
#     ax.set_title(f'Current time: {round(t_total[frame], 5)}')
#     return [cax]

# ani = animation.FuncAnimation(fig, update, frames=len(u_total), blit=True)

# # Save as GIF
# ani.save('Natural Timestepping Cahn-Hilliard Coarsening.gif', writer='pillow', fps=10)
